# %%
from selenium import webdriver

# %%
"""Setting up Chrome webdriver to use LA Galaxy game list url"""

url ='https://www.stubhub.com/la-galaxy-tickets/performer/12587/'
driver = webdriver.Chrome()
driver.get(url)

# %%
"""If there is 'See More Events tab on bottom to show more games, click. Otherwise, continue"""
try:
    more = driver.find_element_by_class_name('EventListPanel__Footer')
    if more:
        more.click()
except:
    pass

"""Collecting all the ticket page links for each game"""
sites = []


"""Scraping each game information and printing them out to screen"""

content = driver.find_elements_by_class_name('EventItem__Body')

for info in content:
        
    details = info.find_element_by_class_name('EventItem__Details')
    day = info.find_element_by_class_name('DateStamp__Day').text
    date = info.find_element_by_class_name('DateStamp__MonthDate').text
    print('Day : ',day,' on Date : ',date)
    gameinfo = details.find_element_by_tag_name('a')
    print(gameinfo.text)
    state = details.find_element_by_class_name('EventItem__MixInfo').text.split()
    
    """If time is TBD (To be determined), which is basically all the Parking Pass tabs"""
    if state[0] == 'TBD':
        time = ' '.join(state[0:1])
        city = ' '.join(state[6:])
#         stadium =' '.join(state[3:6]).replace(',','')
        venue = details.find_element_by_class_name('EventItem__VenueInfo').text
        print('Time: ',time,' -',venue)
#         print('Time: ',time,' at',stadium,',',city)
    else:
        time = ' '.join(state[0:2])
        venue = details.find_element_by_class_name('EventItem__VenueInfo').text
#         city = ' '.join(state[5:])
#         stadium = ' '.join(state[3:5]).replace(',','')
        print('Time: ',time,' at',venue)
    
    """Show how much the ticket prices start from, and how many tickets are left if available"""
    try:
        tickets = details.find_element_by_class_name("EventItem__Price").text
        print('There are tickets available from: ',tickets)
    except:
        pass
    try:
        ticksleft = info.find_element_by_class_name("EventItem__Urgency").text
        if ticksleft:
            print('There are ',ticksleft)
    except:
        pass
    
    """Grab the links for each games that will take you to ticket purchase for each game. **Optional**"""
    link = details.find_element_by_class_name('EventItem__TitleLink')
    link_url = link.get_attribute('href')
    print(link.get_attribute('href'))
    sites.append(link_url)
    print('\n')
    

    
"""Print out ticket links for each game **Optional**"""
for each in sites:
    print(each)
    print('\n')
# Out:
# Day :  WED  on Date :  JUL 4
# DC United at LA Galaxy Tickets (Postgame Fireworks)
# Time:  7:30 PM  at StubHub Center, Carson, CA, US
# There are tickets available from:  $28
# There are  Only 5 tickets left at lowest price
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-7-4-2018/event/103405646/
#
#
# Day :  WED  on Date :  JUL 4
# PARKING PASSES ONLY DC United at LA Galaxy
# Time:  TBD  - StubHub Center Parking Lots, Carson, CA, US
# There are tickets available from:  $35
# There are  21 tickets left
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-parking-lots-7-4-2018/event/103405647/
#
#
# Day :  SAT  on Date :  JUL 7
# Columbus Crew at LA Galaxy
# Time:  7:30 PM  at StubHub Center, Carson, CA, US
# There are tickets available from:  $23
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-7-7-2018/event/103405649/
#
#
# Day :  SAT  on Date :  JUL 7
# PARKING PASSES ONLY Columbus Crew at LA Galaxy
# Time:  TBD  - StubHub Center Parking Lots, Carson, CA, US
# There are tickets available from:  $18
# There are  13 tickets left
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-parking-lots-7-7-2018/event/103405650/
#
#
# Day :  SAT  on Date :  JUL 14
# LA Galaxy at New England Revolution
# Time:  7:30 PM  at Gillette Stadium, Foxborough, MA, US
# There are tickets available from:  $29
# https://www.stubhub.com/new-england-revolution-tickets-new-england-revolution-foxborough-gillette-stadium-7-14-2018/event/103406516/
#
#
# Day :  SAT  on Date :  JUL 14
# PARKING PASSES ONLY LA Galaxy at New England Revolution
# Time:  TBD  - Gillette Stadium Parking Lots, Foxborough, MA, US
# There are  0 tickets left
# https://www.stubhub.com/new-england-revolution-tickets-new-england-revolution-foxborough-gillette-stadium-parking-lots-7-14-2018/event/103406517/
#
#
# Day :  SAT  on Date :  JUL 21
# LA Galaxy at Philadelphia Union
# Time:  7:00 PM  at Talen Energy Stadium, Chester, PA, US
# There are tickets available from:  $45
# https://www.stubhub.com/philadelphia-union-tickets-philadelphia-union-chester-talen-energy-stadium-7-21-2018/event/103406136/
#
#
# Day :  SAT  on Date :  JUL 21
# PARKING PASSES ONLY LA Galaxy at Philadelphia Union
# Time:  TBD  - Talen Energy Stadium Parking Lots, Chester, PA, US
# There are tickets available from:  $30
# There are  3 tickets left
# https://www.stubhub.com/philadelphia-union-tickets-philadelphia-union-chester-talen-energy-stadium-parking-lots-7-21-2018/event/103406137/
#
#
# Day :  THU  on Date :  JUL 26
# LA Galaxy at LAFC
# Time:  7:30 PM  at Banc of California Stadium, Los Angeles, California, US
# There are tickets available from:  $99
# https://www.stubhub.com/lafc-tickets-lafc-los-angeles-banc-of-california-stadium-7-26-2018/event/103406317/
#
#
# Day :  THU  on Date :  JUL 26
# PARKING PASSES ONLY LA Galaxy at LAFC
# Time:  TBD  - Banc of California Stadium Lots, Los Angeles, California, US
# There are tickets available from:  $70
# There are  15 tickets left
# https://www.stubhub.com/lafc-tickets-lafc-los-angeles-banc-of-california-stadium-lots-7-26-2018/event/103580047/
#
#
# Day :  SUN  on Date :  JUL 29
# Orlando City SC at LA Galaxy
# Time:  6:30 PM  at StubHub Center, Carson, CA, US
# There are tickets available from:  $22
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-7-29-2018/event/103405653/
#
#
# Day :  SUN  on Date :  JUL 29
# PARKING PASSES ONLY Orlando City SC at LA Galaxy
# Time:  TBD  - StubHub Center Parking Lots, Carson, CA, US
# There are tickets available from:  $20
# There are  14 tickets left
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-parking-lots-7-29-2018/event/103405654/
#
#
# Day :  SAT  on Date :  AUG 4
# LA Galaxy at Colorado Rapids
# Time:  7:00 PM  at Dicks Sporting Goods Park, Commerce City, CO, US
# There are tickets available from:  $40
# https://www.stubhub.com/colorado-rapids-tickets-colorado-rapids-commerce-city-dicks-sporting-goods-park-8-4-2018/event/103406543/
#
#
# Day :  SAT  on Date :  AUG 4
# PARKING PASSES ONLY LA Galaxy at Colorado Rapids
# Time:  TBD  - Dicks Sporting Goods Park Parking Lots, Commerce City, CO, US
# There are  0 tickets left
# https://www.stubhub.com/colorado-rapids-tickets-colorado-rapids-commerce-city-dicks-sporting-goods-park-parking-lots-8-4-2018/event/103406544/
#
#
# Day :  SAT  on Date :  AUG 11
# Minnesota United FC at LA Galaxy
# Time:  7:30 PM  at StubHub Center, Carson, CA, US
# There are tickets available from:  $23
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-8-11-2018/event/103405659/
#
#
# Day :  SAT  on Date :  AUG 11
# PARKING PASSES ONLY Minnesota United FC at LA Galaxy
# Time:  TBD  - StubHub Center Parking Lots, Carson, CA, US
# There are tickets available from:  $20
# There are  14 tickets left
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-parking-lots-8-11-2018/event/103405660/
#
#
# Day :  TUE  on Date :  AUG 14
# Colorado Rapids at LA Galaxy Tickets (Rescheduled from August 29)
# Time:  7:30 PM  at StubHub Center, Carson, CA, US
# There are tickets available from:  $15
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-8-14-2018/event/103405669/
#
#
# Day :  TUE  on Date :  AUG 14
# PARKING PASSES ONLY Colorado Rapids at LA Galaxy
# Time:  TBD  - StubHub Center Parking Lots, Carson, CA, US
# There are tickets available from:  $17
# There are  13 tickets left
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-parking-lots-8-14-2018/event/103405670/
#
#
# Day :  SAT  on Date :  AUG 18
# LA Galaxy at Seattle Sounders FC
# Time:  12:30 PM  at CenturyLink Field, Seattle, WA, US
# There are tickets available from:  $32
# https://www.stubhub.com/seattle-sounders-fc-tickets-seattle-sounders-fc-seattle-centurylink-field-8-18-2018/event/103406048/
#
#
# Day :  SAT  on Date :  AUG 18
# PARKING PASSES ONLY LA Galaxy at Seattle Sounders FC
# Time:  TBD  - CenturyLink Field Parking Lots, Seattle, WA, US
# There are tickets available from:  $25
# There are  9 tickets left
# https://www.stubhub.com/seattle-sounders-fc-tickets-seattle-sounders-fc-seattle-centurylink-field-parking-lots-8-18-2018/event/103406049/
#
#
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-7-4-2018/event/103405646/
#
#
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-parking-lots-7-4-2018/event/103405647/
#
#
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-7-7-2018/event/103405649/
#
#
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-parking-lots-7-7-2018/event/103405650/
#
#
# https://www.stubhub.com/new-england-revolution-tickets-new-england-revolution-foxborough-gillette-stadium-7-14-2018/event/103406516/
#
#
# https://www.stubhub.com/new-england-revolution-tickets-new-england-revolution-foxborough-gillette-stadium-parking-lots-7-14-2018/event/103406517/
#
#
# https://www.stubhub.com/philadelphia-union-tickets-philadelphia-union-chester-talen-energy-stadium-7-21-2018/event/103406136/
#
#
# https://www.stubhub.com/philadelphia-union-tickets-philadelphia-union-chester-talen-energy-stadium-parking-lots-7-21-2018/event/103406137/
#
#
# https://www.stubhub.com/lafc-tickets-lafc-los-angeles-banc-of-california-stadium-7-26-2018/event/103406317/
#
#
# https://www.stubhub.com/lafc-tickets-lafc-los-angeles-banc-of-california-stadium-lots-7-26-2018/event/103580047/
#
#
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-7-29-2018/event/103405653/
#
#
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-parking-lots-7-29-2018/event/103405654/
#
#
# https://www.stubhub.com/colorado-rapids-tickets-colorado-rapids-commerce-city-dicks-sporting-goods-park-8-4-2018/event/103406543/
#
#
# https://www.stubhub.com/colorado-rapids-tickets-colorado-rapids-commerce-city-dicks-sporting-goods-park-parking-lots-8-4-2018/event/103406544/
#
#
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-8-11-2018/event/103405659/
#
#
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-parking-lots-8-11-2018/event/103405660/
#
#
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-8-14-2018/event/103405669/
#
#
# https://www.stubhub.com/la-galaxy-tickets-la-galaxy-carson-stubhub-center-parking-lots-8-14-2018/event/103405670/
#
#
# https://www.stubhub.com/seattle-sounders-fc-tickets-seattle-sounders-fc-seattle-centurylink-field-8-18-2018/event/103406048/
#
#
# https://www.stubhub.com/seattle-sounders-fc-tickets-seattle-sounders-fc-seattle-centurylink-field-parking-lots-8-18-2018/event/103406049/
